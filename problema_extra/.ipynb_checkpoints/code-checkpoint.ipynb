# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os
import random 

IMG_NAME = 'img.jpg'
TREHSHOLD = 0.5

# %%
def getPath(img):
    current_dir = os.getcwd()
    parent_dir = os.path.abspath(os.path.join(current_dir, os.pardir))
    image_path = os.path.join(parent_dir, img)
    return image_path

# %%
def apply_histogram_equalization(image):
    equalized_image = cv2.equalizeHist(image)
    return equalized_image

    
def suggest_and_apply_equalization(image_path):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    if image is None:
        raise ValueError(f"No se pudo cargar la imagen desde la ruta: {image_path}")
    
    value = round(random.random(),2)
    print(f"Valor calculado: {value:.2f}")
    print(f"La imagen {'requiere' if value > TREHSHOLD else 'no requiere'} ecualización.")
    
    plt.figure(figsize=(10, 5))
    plt.figure(figsize=(5, 5))
    plt.title('Imagen Original')
    plt.imshow(image, cmap='gray')
    plt.axis('off')
    plt.show()
        
    if value > TREHSHOLD:
        equalized_image = apply_histogram_equalization(image)                
        plt.figure(figsize=(5, 5))
        plt.title('Imagen Ecualizada')
        plt.imshow(equalized_image, cmap='gray')
        plt.axis('off')
        
    plt.show()

# %%
image_path = getPath(IMG_NAME)
print(image_path)
suggest_and_apply_equalization(image_path)
# Out:
# C:\Users\gerda\Documents\Maestria\Text Mining & Image Recognition\gdvr-textMining_Lab2\img.jpg
# Valor calculado: 0.54
# La imagen requiere ecualización.
